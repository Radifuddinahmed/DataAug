# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score, KFold
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from datetime import datetime

#output='depth'
#input_file='DataAug/LPBF_Final_Dataset/LPBF_Dataset_Normalized_Depth.csv'

output='width'
input_file='DataAug/LPBF_Final_Dataset/LPBF_Dataset_Normalized_Width.csv'

df = pd.read_csv(input_file)

X=df.iloc[:, :-1]
y=df.iloc[:, -1]

# Specify different kernels and their parameter grids
kernels = ['linear', 'poly', 'rbf']
C_values = [0.0001, 0.001, 0.01,0.1, 1, 10, 100]
degree_values = [2, 3, 4,5,6]
gamma_values = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]

cv = KFold(n_splits=10, shuffle=True, random_state=42)

poly_list = []

for kernel in kernels:
    for C in C_values:
        if kernel == 'poly':
            for degree in degree_values:
                model = make_pipeline(StandardScaler(), SVR(kernel=kernel, C=C, degree=degree))
                
                mse_scores = -cross_val_score(model, X, y, cv=cv, scoring='neg_mean_squared_error')
                mae_scores = -cross_val_score(model, X, y, cv=cv, scoring='neg_mean_absolute_error')
                r2_scores = cross_val_score(model, X, y, cv=cv, scoring='r2')
        
            
                # Calculate metrics
                mse = mse_scores.mean()
                mae = mae_scores.mean()
                corr = r2_scores.mean()
        
                # Calculate additional metrics
                rmse = np.sqrt(mse)
                rae = mae / np.mean(np.abs(y - np.mean(y)))
                rrse = rmse / np.sqrt(np.mean((y - np.mean(y))**2))

                poly_list.append({
                    'Kernel': kernel,
                    'C': C,
                    'degree/gamma': degree,
                    'R-squared': corr,
                    'MAE': mae,
                    'MSE': mse,
                    'RMSE': rmse,
                    'RAE': rae,
                    'RRSE': rrse
                })
                        
                
                scores = cross_val_score(model, X, y, cv=KFold(n_splits=10, shuffle=True, random_state=42),
                                         scoring='neg_mean_squared_error')
                print(f"Kernel: {kernel}, C: {C}, Degree: {degree}, Mean Squared Error: {-scores.mean()}")
        elif kernel == 'rbf':
            for gamma in gamma_values:
                model = make_pipeline(StandardScaler(), SVR(kernel=kernel, C=C, gamma=gamma))
                

                mse_scores = -cross_val_score(model, X, y, cv=cv, scoring='neg_mean_squared_error')
                mae_scores = -cross_val_score(model, X, y, cv=cv, scoring='neg_mean_absolute_error')
                r2_scores = cross_val_score(model, X, y, cv=cv, scoring='r2')
        
            
                # Calculate metrics
                mse = mse_scores.mean()
                mae = mae_scores.mean()
                corr = r2_scores.mean()
        
                # Calculate additional metrics
                rmse = np.sqrt(mse)
                rae = mae / np.mean(np.abs(y - np.mean(y)))
                rrse = rmse / np.sqrt(np.mean((y - np.mean(y))**2))

                poly_list.append({
                    'Kernel': kernel,
                    'C': C,
                    'degree/gamma': gamma,
                    'R-squared': corr,
                    'MAE': mae,
                    'MSE': mse,
                    'RMSE': rmse,
                    'RAE': rae,
                    'RRSE': rrse
                })
                
                scores = cross_val_score(model, X, y, cv=KFold(n_splits=10, shuffle=True, random_state=42),
                                         scoring='neg_mean_squared_error')
                print(f"Kernel: {kernel}, C: {C}, Gamma: {gamma}, Mean Squared Error: {-scores.mean()}")
        else:
            model = make_pipeline(StandardScaler(), SVR(kernel=kernel, C=C))
            scores = cross_val_score(model, X, y, cv=KFold(n_splits=10, shuffle=True, random_state=42),
                                     scoring='neg_mean_squared_error')
            print(f"Kernel: {kernel}, C: {C}, Mean Squared Error: {-scores.mean()}")
            
            mse_scores = -cross_val_score(model, X, y, cv=cv, scoring='neg_mean_squared_error')
            mae_scores = -cross_val_score(model, X, y, cv=cv, scoring='neg_mean_absolute_error')
            r2_scores = cross_val_score(model, X, y, cv=cv, scoring='r2')
    
        
            # Calculate metrics
            mse = mse_scores.mean()
            mae = mae_scores.mean()
            corr = r2_scores.mean()
    
            # Calculate additional metrics
            rmse = np.sqrt(mse)
            rae = mae / np.mean(np.abs(y - np.mean(y)))
            rrse = rmse / np.sqrt(np.mean((y - np.mean(y))**2))
    
            poly_list.append({
                'Kernel': kernel,
                'C': C,
                'degree/gamma': 0,
                'R-squared': corr,
                'MAE': mae,
                'MSE': mse,
                'RMSE': rmse,
                'RAE': rae,
                'RRSE': rrse
            })






poly_results = pd.DataFrame(poly_list)
# Save results to a CSV file

timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
filename = f'{output}_svr_hp_results_{timestamp}.csv'

poly_results.to_csv(filename, index=False)
# Out:
# Kernel: linear, C: 0.0001, Mean Squared Error: 0.008030144402637862
# Kernel: linear, C: 0.001, Mean Squared Error: 0.0073175368333659035
# Kernel: linear, C: 0.01, Mean Squared Error: 0.003158239320210661
# Kernel: linear, C: 0.1, Mean Squared Error: 0.0031257469144662453
# Kernel: linear, C: 1, Mean Squared Error: 0.00315082496291771
# Kernel: linear, C: 10, Mean Squared Error: 0.0031497472700426376
# Kernel: linear, C: 100, Mean Squared Error: 0.0031516302240085893
# Kernel: poly, C: 0.0001, Degree: 2, Mean Squared Error: 0.007738693723935236
# Kernel: poly, C: 0.0001, Degree: 3, Mean Squared Error: 0.00749281661211783
# Kernel: poly, C: 0.0001, Degree: 4, Mean Squared Error: 0.007277160551202708
# Kernel: poly, C: 0.0001, Degree: 5, Mean Squared Error: 0.00762363647220316
# Kernel: poly, C: 0.0001, Degree: 6, Mean Squared Error: 0.01116045830252298
# Kernel: poly, C: 0.001, Degree: 2, Mean Squared Error: 0.007015755013481439
# Kernel: poly, C: 0.001, Degree: 3, Mean Squared Error: 0.006913572318938905
# Kernel: poly, C: 0.001, Degree: 4, Mean Squared Error: 0.006328412096275412
# Kernel: poly, C: 0.001, Degree: 5, Mean Squared Error: 0.0071707578837187326
# Kernel: poly, C: 0.001, Degree: 6, Mean Squared Error: 0.01331069177051126
# Kernel: poly, C: 0.01, Degree: 2, Mean Squared Error: 0.004796085508129712
# Kernel: poly, C: 0.01, Degree: 3, Mean Squared Error: 0.0056917142004773
# Kernel: poly, C: 0.01, Degree: 4, Mean Squared Error: 0.005277407423681592
# Kernel: poly, C: 0.01, Degree: 5, Mean Squared Error: 0.008244877010980357
# Kernel: poly, C: 0.01, Degree: 6, Mean Squared Error: 0.02732176523552987
# Kernel: poly, C: 0.1, Degree: 2, Mean Squared Error: 0.005719383991960159
# Kernel: poly, C: 0.1, Degree: 3, Mean Squared Error: 0.005744640661472641
# Kernel: poly, C: 0.1, Degree: 4, Mean Squared Error: 0.017361596807826857
# Kernel: poly, C: 0.1, Degree: 5, Mean Squared Error: 0.07774337804805352
# Kernel: poly, C: 0.1, Degree: 6, Mean Squared Error: 0.20334913612243016
# Kernel: poly, C: 1, Degree: 2, Mean Squared Error: 0.008667192415308545
# Kernel: poly, C: 1, Degree: 3, Mean Squared Error: 0.023483647709562953
# Kernel: poly, C: 1, Degree: 4, Mean Squared Error: 0.04434767347046122
# Kernel: poly, C: 1, Degree: 5, Mean Squared Error: 0.7357189141954672
# Kernel: poly, C: 1, Degree: 6, Mean Squared Error: 2.0336382115089227
# Kernel: poly, C: 10, Degree: 2, Mean Squared Error: 0.010859656893687435
# Kernel: poly, C: 10, Degree: 3, Mean Squared Error: 0.034155982697280304
# Kernel: poly, C: 10, Degree: 4, Mean Squared Error: 0.2986229158803794
# Kernel: poly, C: 10, Degree: 5, Mean Squared Error: 5.411415991772387
# Kernel: poly, C: 10, Degree: 6, Mean Squared Error: 43.70308159353446
# Kernel: poly, C: 100, Degree: 2, Mean Squared Error: 0.01089170225287418
# Kernel: poly, C: 100, Degree: 3, Mean Squared Error: 0.07577643395743558
# Kernel: poly, C: 100, Degree: 4, Mean Squared Error: 0.3545128924342828
# Kernel: poly, C: 100, Degree: 5, Mean Squared Error: 26.09034422044622
# Kernel: poly, C: 100, Degree: 6, Mean Squared Error: 63.01936383355828
# Kernel: rbf, C: 0.0001, Gamma: 0.0001, Mean Squared Error: 0.008029896177992211
# Kernel: rbf, C: 0.0001, Gamma: 0.001, Mean Squared Error: 0.008026604298877128
# Kernel: rbf, C: 0.0001, Gamma: 0.01, Mean Squared Error: 0.008025399228220141
# Kernel: rbf, C: 0.0001, Gamma: 0.1, Mean Squared Error: 0.008025812106836464
# Kernel: rbf, C: 0.0001, Gamma: 1, Mean Squared Error: 0.008109031146700448
# Kernel: rbf, C: 0.0001, Gamma: 10, Mean Squared Error: 0.008104430365789537
# Kernel: rbf, C: 0.0001, Gamma: 100, Mean Squared Error: 0.008052736833888987
# Kernel: rbf, C: 0.001, Gamma: 0.0001, Mean Squared Error: 0.008029353231217335
# Kernel: rbf, C: 0.001, Gamma: 0.001, Mean Squared Error: 0.008026006521476729
# Kernel: rbf, C: 0.001, Gamma: 0.01, Mean Squared Error: 0.007990715906691166
# Kernel: rbf, C: 0.001, Gamma: 0.1, Mean Squared Error: 0.008069331123383813
# Kernel: rbf, C: 0.001, Gamma: 1, Mean Squared Error: 0.00834374472965995
# Kernel: rbf, C: 0.001, Gamma: 10, Mean Squared Error: 0.008387699609010025
# Kernel: rbf, C: 0.001, Gamma: 100, Mean Squared Error: 0.008216536701684924
# Kernel: rbf, C: 0.01, Gamma: 0.0001, Mean Squared Error: 0.008029108475298901
# Kernel: rbf, C: 0.01, Gamma: 0.001, Mean Squared Error: 0.007977243623984732
# Kernel: rbf, C: 0.01, Gamma: 0.01, Mean Squared Error: 0.008066006937318158
# Kernel: rbf, C: 0.01, Gamma: 0.1, Mean Squared Error: 0.007957957318013286
# Kernel: rbf, C: 0.01, Gamma: 1, Mean Squared Error: 0.0094957753502614
# Kernel: rbf, C: 0.01, Gamma: 10, Mean Squared Error: 0.009231232276576243
# Kernel: rbf, C: 0.01, Gamma: 100, Mean Squared Error: 0.008825931027008734
# Kernel: rbf, C: 0.1, Gamma: 0.0001, Mean Squared Error: 0.00797454527226655
# Kernel: rbf, C: 0.1, Gamma: 0.001, Mean Squared Error: 0.008176493828203724
# Kernel: rbf, C: 0.1, Gamma: 0.01, Mean Squared Error: 0.007135508003920809
# Kernel: rbf, C: 0.1, Gamma: 0.1, Mean Squared Error: 0.007301868034623062
# Kernel: rbf, C: 0.1, Gamma: 1, Mean Squared Error: 0.009631970585156423
# Kernel: rbf, C: 0.1, Gamma: 10, Mean Squared Error: 0.011181697171848694
# Kernel: rbf, C: 0.1, Gamma: 100, Mean Squared Error: 0.010685829104992595
# Kernel: rbf, C: 1, Gamma: 0.0001, Mean Squared Error: 0.00815965316491812
# Kernel: rbf, C: 1, Gamma: 0.001, Mean Squared Error: 0.0061184126845517835
# Kernel: rbf, C: 1, Gamma: 0.01, Mean Squared Error: 0.0030682774147420466
# Kernel: rbf, C: 1, Gamma: 0.1, Mean Squared Error: 0.003363531849120788
# Kernel: rbf, C: 1, Gamma: 1, Mean Squared Error: 0.009348906135710223
# Kernel: rbf, C: 1, Gamma: 10, Mean Squared Error: 0.011751974060616122
# Kernel: rbf, C: 1, Gamma: 100, Mean Squared Error: 0.0117062245970973
# Kernel: rbf, C: 10, Gamma: 0.0001, Mean Squared Error: 0.005964832212334426
# Kernel: rbf, C: 10, Gamma: 0.001, Mean Squared Error: 0.0028070965452354976
# Kernel: rbf, C: 10, Gamma: 0.01, Mean Squared Error: 0.0024590729953546074
# Kernel: rbf, C: 10, Gamma: 0.1, Mean Squared Error: 0.003613023050053932
# Kernel: rbf, C: 10, Gamma: 1, Mean Squared Error: 0.009348906135710223
# Kernel: rbf, C: 10, Gamma: 10, Mean Squared Error: 0.011751974060616122
# Kernel: rbf, C: 10, Gamma: 100, Mean Squared Error: 0.0117062245970973
# Kernel: rbf, C: 100, Gamma: 0.0001, Mean Squared Error: 0.002860298435510215
# Kernel: rbf, C: 100, Gamma: 0.001, Mean Squared Error: 0.002767938631791595
# Kernel: rbf, C: 100, Gamma: 0.01, Mean Squared Error: 0.0023350303423732093
# Kernel: rbf, C: 100, Gamma: 0.1, Mean Squared Error: 0.0032353641007183964
# Kernel: rbf, C: 100, Gamma: 1, Mean Squared Error: 0.009348906135710223
# Kernel: rbf, C: 100, Gamma: 10, Mean Squared Error: 0.011751974060616122
# Kernel: rbf, C: 100, Gamma: 100, Mean Squared Error: 0.0117062245970973
