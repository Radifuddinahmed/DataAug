# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.datasets import make_regression
from datetime import datetime

output='depth'
input_file='DataAug/LPBF_Final_Dataset/LPBF_Dataset_Normalized_Depth.csv'

#output='width'
#input_file='DataAug/LPBF_Final_Dataset/LPBF_Dataset_Normalized_Width.csv'

df = pd.read_csv(input_file)

X=df.iloc[:, :-1]
y=df.iloc[:, -1]

# Specify different hyperparameter combinations
n_estimators_values = [10, 50, 100, 200]
max_depth_values = [None, 10, 20, 30]
min_samples_split_values = [2, 5, 10]
min_samples_leaf_values = [1, 2, 4]

poly_list=[]
cv = KFold(n_splits=10, shuffle=True, random_state=42)
# Perform 10-fold cross-validation for each combination of hyperparameters
for n_estimators in n_estimators_values:
    for max_depth in max_depth_values:
        for min_samples_split in min_samples_split_values:
            for min_samples_leaf in min_samples_leaf_values:
                model = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth,
                                              min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf,
                                              random_state=42)

                mse_scores = -cross_val_score(model, X, y, cv=cv, scoring='neg_mean_squared_error')
                mae_scores = -cross_val_score(model, X, y, cv=cv, scoring='neg_mean_absolute_error')
                r2_scores = cross_val_score(model, X, y, cv=cv, scoring='r2')
        
            
                # Calculate metrics
                mse = mse_scores.mean()
                mae = mae_scores.mean()
                corr = r2_scores.mean()
        
                # Calculate additional metrics
                rmse = np.sqrt(mse)
                rae = mae / np.mean(np.abs(y - np.mean(y)))
                rrse = rmse / np.sqrt(np.mean((y - np.mean(y))**2))

                poly_list.append({
                    'n_estimators': n_estimators,
                    'max_depth': max_depth,
                    'min_samples_split': min_samples_split,
                    'min_samples_leaf': min_samples_leaf,
                    'R-squared': corr,
                    'MAE': mae,
                    'MSE': mse,
                    'RMSE': rmse,
                    'RAE': rae,
                    'RRSE': rrse
                })

                scores = cross_val_score(model, X, y, cv=cv,
                                         scoring='neg_mean_squared_error')
                
                # Display the results
                print(f"n_estimators: {n_estimators}, max_depth: {max_depth}, min_samples_split: {min_samples_split}, "
                      f"min_samples_leaf: {min_samples_leaf}, Mean Squared Error: {-scores.mean()}")

poly_results = pd.DataFrame(poly_list)
# Save results to a CSV file

timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
filename = f'{output}_rf_hp_results_{timestamp}.csv'

poly_results.to_csv(filename, index=False)
# Out:
# n_estimators: 10, max_depth: None, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0012325690973029764
# n_estimators: 10, max_depth: None, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.001439329339609494
# n_estimators: 10, max_depth: None, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.001343280223756206
# n_estimators: 10, max_depth: None, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.001364247245221013
# n_estimators: 10, max_depth: None, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.001419553952676661
# n_estimators: 10, max_depth: None, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.001343280223756206
# n_estimators: 10, max_depth: None, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0015314050210944925
# n_estimators: 10, max_depth: None, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.0015321978040734783
# n_estimators: 10, max_depth: None, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0014323844977657497
# n_estimators: 10, max_depth: 10, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0012466792311338272
# n_estimators: 10, max_depth: 10, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0014329814432441795
# n_estimators: 10, max_depth: 10, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.0013455061403241137
# n_estimators: 10, max_depth: 10, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.00136493076117129
# n_estimators: 10, max_depth: 10, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0014372398513841746
# n_estimators: 10, max_depth: 10, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.0013455061403241137
# n_estimators: 10, max_depth: 10, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0015242380177384117
# n_estimators: 10, max_depth: 10, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.0015325321902660307
# n_estimators: 10, max_depth: 10, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0014330014269133067
# n_estimators: 10, max_depth: 20, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0012329354168367104
# n_estimators: 10, max_depth: 20, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.001439329339609494
# n_estimators: 10, max_depth: 20, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.001343280223756206
# n_estimators: 10, max_depth: 20, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.001364247245221013
# n_estimators: 10, max_depth: 20, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.001419553952676661
# n_estimators: 10, max_depth: 20, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.001343280223756206
# n_estimators: 10, max_depth: 20, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0015314050210944925
# n_estimators: 10, max_depth: 20, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.0015321978040734783
# n_estimators: 10, max_depth: 20, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0014323844977657497
# n_estimators: 10, max_depth: 30, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0012325690973029764
# n_estimators: 10, max_depth: 30, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.001439329339609494
# n_estimators: 10, max_depth: 30, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.001343280223756206
# n_estimators: 10, max_depth: 30, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.001364247245221013
# n_estimators: 10, max_depth: 30, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.001419553952676661
# n_estimators: 10, max_depth: 30, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.001343280223756206
# n_estimators: 10, max_depth: 30, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0015314050210944925
# n_estimators: 10, max_depth: 30, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.0015321978040734783
# n_estimators: 10, max_depth: 30, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0014323844977657497
# n_estimators: 50, max_depth: None, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0011879093201038454
# n_estimators: 50, max_depth: None, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012344455058505442
# n_estimators: 50, max_depth: None, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.0012926721216379637
# n_estimators: 50, max_depth: None, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.001193977476923208
# n_estimators: 50, max_depth: None, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012188086007360564
# n_estimators: 50, max_depth: None, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.0012926721216379637
# n_estimators: 50, max_depth: None, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013902252180775351
# n_estimators: 50, max_depth: None, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.001405456224177038
# n_estimators: 50, max_depth: None, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013681117589544663
# n_estimators: 50, max_depth: 10, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0011966286743762483
# n_estimators: 50, max_depth: 10, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012411644512714767
# n_estimators: 50, max_depth: 10, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.0012940510321161405
# n_estimators: 50, max_depth: 10, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.00119595339493753
# n_estimators: 50, max_depth: 10, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012258357548787483
# n_estimators: 50, max_depth: 10, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.0012940510321161405
# n_estimators: 50, max_depth: 10, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013919071958728674
# n_estimators: 50, max_depth: 10, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.001407531267059388
# n_estimators: 50, max_depth: 10, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013693364035928823
# n_estimators: 50, max_depth: 20, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0011874027566084562
# n_estimators: 50, max_depth: 20, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012344455058505442
# n_estimators: 50, max_depth: 20, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.0012926721216379637
# n_estimators: 50, max_depth: 20, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.001193977476923208
# n_estimators: 50, max_depth: 20, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012188086007360564
# n_estimators: 50, max_depth: 20, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.0012926721216379637
# n_estimators: 50, max_depth: 20, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013902252180775351
# n_estimators: 50, max_depth: 20, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.001405456224177038
# n_estimators: 50, max_depth: 20, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013681117589544663
# n_estimators: 50, max_depth: 30, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0011879093201038454
# n_estimators: 50, max_depth: 30, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012344455058505442
# n_estimators: 50, max_depth: 30, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.0012926721216379637
# n_estimators: 50, max_depth: 30, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.001193977476923208
# n_estimators: 50, max_depth: 30, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012188086007360564
# n_estimators: 50, max_depth: 30, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.0012926721216379637
# n_estimators: 50, max_depth: 30, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013902252180775351
# n_estimators: 50, max_depth: 30, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.001405456224177038
# n_estimators: 50, max_depth: 30, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013681117589544663
# n_estimators: 100, max_depth: None, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0012027344714052968
# n_estimators: 100, max_depth: None, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012388531879412269
# n_estimators: 100, max_depth: None, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.001322092132972741
# n_estimators: 100, max_depth: None, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.0011865662298141916
# n_estimators: 100, max_depth: None, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012210811785527058
# n_estimators: 100, max_depth: None, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.001322092132972741
# n_estimators: 100, max_depth: None, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013796527670014887
# n_estimators: 100, max_depth: None, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.0013948105819553787
# n_estimators: 100, max_depth: None, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013887966339295387
# n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.001209582484965126
# n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012444058854233192
# n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.001323437706621366
# n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.0011896870519658817
# n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012248267195872616
# n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.001323437706621366
# n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013825707541471751
# n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.0013970952605213264
# n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.001389823655907616
# n_estimators: 100, max_depth: 20, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.001202298595432481
# n_estimators: 100, max_depth: 20, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012388531879412269
# n_estimators: 100, max_depth: 20, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.001322092132972741
# n_estimators: 100, max_depth: 20, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.0011865662301815993
# n_estimators: 100, max_depth: 20, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012210811785527058
# n_estimators: 100, max_depth: 20, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.001322092132972741
# n_estimators: 100, max_depth: 20, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013796527670014887
# n_estimators: 100, max_depth: 20, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.0013948105819553787
# n_estimators: 100, max_depth: 20, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013887966339295387
# n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0012027344714052968
# n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012388531879412269
# n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.001322092132972741
# n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.0011865662298141916
# n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012210811785527058
# n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.001322092132972741
# n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013796527670014887
# n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.0013948105819553787
# n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013887966339295387
# n_estimators: 200, max_depth: None, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0011692618565122795
# n_estimators: 200, max_depth: None, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012220368849244871
# n_estimators: 200, max_depth: None, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.0013168422064212906
# n_estimators: 200, max_depth: None, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.0011736076717808988
# n_estimators: 200, max_depth: None, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012076672308878856
# n_estimators: 200, max_depth: None, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.0013168422064212906
# n_estimators: 200, max_depth: None, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013796851618742717
# n_estimators: 200, max_depth: None, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.001382318347876391
# n_estimators: 200, max_depth: None, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013876300016499206
# n_estimators: 200, max_depth: 10, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.00117782212953604
# n_estimators: 200, max_depth: 10, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012280625535902945
# n_estimators: 200, max_depth: 10, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.0013183942616300948
# n_estimators: 200, max_depth: 10, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.0011780595123069024
# n_estimators: 200, max_depth: 10, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012141715166087107
# n_estimators: 200, max_depth: 10, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.0013183942616300948
# n_estimators: 200, max_depth: 10, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013809069316702855
# n_estimators: 200, max_depth: 10, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.0013846792070268865
# n_estimators: 200, max_depth: 10, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013883411845219114
# n_estimators: 200, max_depth: 20, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0011691289295435953
# n_estimators: 200, max_depth: 20, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012220368849244871
# n_estimators: 200, max_depth: 20, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.0013168422064212906
# n_estimators: 200, max_depth: 20, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.0011736076698557133
# n_estimators: 200, max_depth: 20, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012076672308878856
# n_estimators: 200, max_depth: 20, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.0013168422064212906
# n_estimators: 200, max_depth: 20, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013796851618742717
# n_estimators: 200, max_depth: 20, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.001382318347876391
# n_estimators: 200, max_depth: 20, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013876300016499206
# n_estimators: 200, max_depth: 30, min_samples_split: 2, min_samples_leaf: 1, Mean Squared Error: 0.0011692618565122795
# n_estimators: 200, max_depth: 30, min_samples_split: 2, min_samples_leaf: 2, Mean Squared Error: 0.0012220368849244871
# n_estimators: 200, max_depth: 30, min_samples_split: 2, min_samples_leaf: 4, Mean Squared Error: 0.0013168422064212906
# n_estimators: 200, max_depth: 30, min_samples_split: 5, min_samples_leaf: 1, Mean Squared Error: 0.0011736076717808988
# n_estimators: 200, max_depth: 30, min_samples_split: 5, min_samples_leaf: 2, Mean Squared Error: 0.0012076672308878856
# n_estimators: 200, max_depth: 30, min_samples_split: 5, min_samples_leaf: 4, Mean Squared Error: 0.0013168422064212906
# n_estimators: 200, max_depth: 30, min_samples_split: 10, min_samples_leaf: 1, Mean Squared Error: 0.0013796851618742717
# n_estimators: 200, max_depth: 30, min_samples_split: 10, min_samples_leaf: 2, Mean Squared Error: 0.001382318347876391
# n_estimators: 200, max_depth: 30, min_samples_split: 10, min_samples_leaf: 4, Mean Squared Error: 0.0013876300016499206
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 73
#      70 poly_results = pd.DataFrame(poly_list)
#      71 # Save results to a CSV file
# ---> 73 timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
#      74 filename = f'{output}_rf_hp_results_{timestamp}.csv'
#      76 poly_results.to_csv(filename, index=False)
#
# NameError: name 'datetime' is not defined
